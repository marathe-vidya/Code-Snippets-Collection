# %% [markdown]
# # 2.1.1 Object creation
#
# See the Intro to data structures section.
# Creating a Series by passing a list of values, letting pandas create a default integer index:

# %%
import pandas as pd
import numpy as np

s = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# Creating a DataFrame by passing a NumPy array, with a datetime index and labeled columns:

# %%
dates = pd.date_range("20130101", periods=20)

# %%
dates    #generating dates values in yyyy-mm-dd
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08',
#                '2013-01-09', '2013-01-10', '2013-01-11', '2013-01-12',
#                '2013-01-13', '2013-01-14', '2013-01-15', '2013-01-16',
#                '2013-01-17', '2013-01-18', '2013-01-19', '2013-01-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates_df = pd.DataFrame(np.random.randn(20, 4), index=dates, columns=list("ABCD"))

# %%
dates_df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.734146 -0.190876 -0.911595  2.421994
# 2013-01-02 -0.094941  0.126662 -1.368024  0.413055
# 2013-01-03  0.698640 -2.003477 -0.634654 -0.140863
# 2013-01-04 -0.560187  0.215529  0.143074  0.078621
# 2013-01-05  1.503066 -0.244649 -0.611939 -0.062458
# 2013-01-06  1.483063  1.330993 -0.500048  0.504062
# 2013-01-07 -0.624480 -0.099181 -0.593857 -0.341433
# 2013-01-08  1.148196  2.071855  2.496152 -0.273628
# 2013-01-09  1.101611  2.321021  0.607663  0.147131
# 2013-01-10 -0.400339 -0.116897  1.422844  0.752116
# 2013-01-11 -0.892403  0.770240  0.472916  0.029650
# 2013-01-12 -1.196740  1.506057 -0.449370 -0.375858
# 2013-01-13 -0.292403 -0.284467  0.853434 -0.332014
# 2013-01-14 -0.736429  0.649422 -1.048558 -1.455204
# 2013-01-15 -1.134599  0.120651  0.494616  0.672023
# 2013-01-16 -1.399483  0.388493  2.363576 -0.196758
# 2013-01-17  1.991348 -0.077780  1.330151  0.482543
# 2013-01-18  0.811369 -0.942770 -0.225208  1.935826
# 2013-01-19 -0.046484  0.100356  0.875249 -1.555426
# 2013-01-20 -0.409164  0.143737 -0.369086 -0.109715

# %% [markdown]
# # 2.1.2 Viewing data
#
# Here is how to view the top and bottom rows of the frame:

# %%
dates_df.head(7)  # if dataset is large... head will print first few (7 in our example) values
# Out:
#                    A         B         C         D
# 2013-01-01 -0.349881 -1.309025 -0.009574 -0.944653
# 2013-01-02 -1.140735  2.176288  0.776429  0.670674
# 2013-01-03  0.377398 -0.526109 -1.673832  0.108239
# 2013-01-04  0.125482 -0.720712  0.409209  0.712693
# 2013-01-05  0.571175  1.046238  0.689739  1.107548
# 2013-01-06 -0.856939 -0.319108  1.607833 -1.837946
# 2013-01-07  0.649997  0.331403 -0.205147 -0.941460

# %%
dates_df.tail(7)
# Out:
#                    A         B         C         D
# 2013-01-14 -1.229706 -0.072450  0.308444 -1.151430
# 2013-01-15 -0.401995 -0.477292  1.018245 -0.513386
# 2013-01-16  1.345684 -0.399930  0.524609 -0.055509
# 2013-01-17  1.061627 -0.692883  0.562767  0.290116
# 2013-01-18 -0.943117 -0.060696 -2.694237  0.891378
# 2013-01-19 -1.611548 -0.137289 -0.496073  1.060174
# 2013-01-20 -1.425491  0.635629  0.146169  0.151678

# %%
dates_df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
dates_df.dtypes  #prints data types of columns present in datadrame
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# dtype: object

# %%
#describe() shows a quick statistic summary of your data:

dates_df.describe()
# Out:
#                A          B          C          D
# count  20.000000  20.000000  20.000000  20.000000
# mean   -0.201697  -0.001890   0.163515  -0.075433
# std     1.002946   0.988199   1.069592   0.942960
# min    -1.611548  -1.339204  -2.694237  -1.837946
# 25%    -1.077032  -0.567803  -0.257996  -0.942258
# 50%    -0.375938  -0.104869   0.228859   0.026365
# 75%     0.701537   0.407459   0.711411   0.741639
# max     1.345684   2.176288   1.888359   1.401868

# %%
#Transposing your data Transpose=exchangeing rows with columns

df_T=dates_df.T

df_T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06  \
# A   -0.349881   -1.140735    0.377398    0.125482    0.571175   -0.856939
# B   -1.309025    2.176288   -0.526109   -0.720712    1.046238   -0.319108
# C   -0.009574    0.776429   -1.673832    0.409209    0.689739    1.607833
# D   -0.944653    0.670674    0.108239    0.712693    1.107548   -1.837946
#
#    2013-01-07  2013-01-08  2013-01-09  2013-01-10  2013-01-11  2013-01-12  \
# A    0.649997   -1.055797    0.856158    0.941766   -0.843286   -1.332849
# B    0.331403   -1.339204    0.728462    0.281997    2.136635   -1.316632
# C   -0.205147    1.425190    1.888359   -0.416541   -0.743712    0.003142
# D   -0.941460   -1.425070    1.401868   -0.961146    0.828478   -0.338552
#
#    2013-01-13  2013-01-14  2013-01-15  2013-01-16  2013-01-17  2013-01-18  \
# A    1.228112   -1.229706   -0.401995    1.345684    1.061627   -0.943117
# B   -0.003124   -0.072450   -0.477292   -0.399930   -0.692883   -0.060696
# C    0.149273    0.308444    1.018245    0.524609    0.562767   -2.694237
# D   -0.562350   -1.151430   -0.513386   -0.055509    0.290116    0.891378
#
#    2013-01-19  2013-01-20
# A   -1.611548   -1.425491
# B   -0.137289    0.635629
# C   -0.496073    0.146169
# D    1.060174    0.151678

# %%
#Sorting by an axis:


dates_df.sort_index(axis=1,ascending=False) #axis=1 sort by columns in reverse order
# Out:
#                    D         C         B         A
# 2013-01-01 -0.944653 -0.009574 -1.309025 -0.349881
# 2013-01-02  0.670674  0.776429  2.176288 -1.140735
# 2013-01-03  0.108239 -1.673832 -0.526109  0.377398
# 2013-01-04  0.712693  0.409209 -0.720712  0.125482
# 2013-01-05  1.107548  0.689739  1.046238  0.571175
# 2013-01-06 -1.837946  1.607833 -0.319108 -0.856939
# 2013-01-07 -0.941460 -0.205147  0.331403  0.649997
# 2013-01-08 -1.425070  1.425190 -1.339204 -1.055797
# 2013-01-09  1.401868  1.888359  0.728462  0.856158
# 2013-01-10 -0.961146 -0.416541  0.281997  0.941766
# 2013-01-11  0.828478 -0.743712  2.136635 -0.843286
# 2013-01-12 -0.338552  0.003142 -1.316632 -1.332849
# 2013-01-13 -0.562350  0.149273 -0.003124  1.228112
# 2013-01-14 -1.151430  0.308444 -0.072450 -1.229706
# 2013-01-15 -0.513386  1.018245 -0.477292 -0.401995
# 2013-01-16 -0.055509  0.524609 -0.399930  1.345684
# 2013-01-17  0.290116  0.562767 -0.692883  1.061627
# 2013-01-18  0.891378 -2.694237 -0.060696 -0.943117
# 2013-01-19  1.060174 -0.496073 -0.137289 -1.611548
# 2013-01-20  0.151678  0.146169  0.635629 -1.425491

# %%
dates_df.sort_index(axis=0,ascending=False)  #axis 0=rowise sort
# Out:
#                    A         B         C         D
# 2013-01-20 -1.425491  0.635629  0.146169  0.151678
# 2013-01-19 -1.611548 -0.137289 -0.496073  1.060174
# 2013-01-18 -0.943117 -0.060696 -2.694237  0.891378
# 2013-01-17  1.061627 -0.692883  0.562767  0.290116
# 2013-01-16  1.345684 -0.399930  0.524609 -0.055509
# 2013-01-15 -0.401995 -0.477292  1.018245 -0.513386
# 2013-01-14 -1.229706 -0.072450  0.308444 -1.151430
# 2013-01-13  1.228112 -0.003124  0.149273 -0.562350
# 2013-01-12 -1.332849 -1.316632  0.003142 -0.338552
# 2013-01-11 -0.843286  2.136635 -0.743712  0.828478
# 2013-01-10  0.941766  0.281997 -0.416541 -0.961146
# 2013-01-09  0.856158  0.728462  1.888359  1.401868
# 2013-01-08 -1.055797 -1.339204  1.425190 -1.425070
# 2013-01-07  0.649997  0.331403 -0.205147 -0.941460
# 2013-01-06 -0.856939 -0.319108  1.607833 -1.837946
# 2013-01-05  0.571175  1.046238  0.689739  1.107548
# 2013-01-04  0.125482 -0.720712  0.409209  0.712693
# 2013-01-03  0.377398 -0.526109 -1.673832  0.108239
# 2013-01-02 -1.140735  2.176288  0.776429  0.670674
# 2013-01-01 -0.349881 -1.309025 -0.009574 -0.944653

# %% [markdown]
# # Now onwards we will work on NVIDEA GPU SPECS DATASET

# %%
#lets read data from CSV File
gpu_df=pd.read_csv("gpu_specs_v6.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 #lets read data from CSV File
# ----> 2 gpu_df=pd.read_csv("gpu_specs_v6.csv")
#
# NameError: name 'pd' is not defined

# %%
gpu_df["manufacturer"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 gpu_df["manufacturer"]
#
# NameError: name 'gpu_df' is not defined

# %%
gpu_df.shape  #describing rows and columns
# Out:
# (2889, 16)

# %%
gpu_df.dtypes
# Out:
# manufacturer      object
# productName       object
# releaseYear      float64
# memSize          float64
# memBusWidth      float64
# gpuClock           int64
# memClock         float64
# unifiedShader    float64
# tmu                int64
# rop                int64
# pixelShader      float64
# vertexShader     float64
# igp               object
# bus               object
# memType           object
# gpuChip           object
# dtype: object

# %%
gpu_df.describe()
# Out:
#        releaseYear      memSize  memBusWidth     gpuClock     memClock  \
# count  2845.000000  2477.000000  2477.000000  2889.000000  2477.000000
# mean   2010.691388     3.113803   274.874445   661.126687   868.578119
# std       6.193125     7.175399   653.163896   374.481450   509.987396
# min    1986.000000     0.000032    32.000000    10.000000     5.000000
# 25%    2006.000000     0.256000   128.000000   400.000000   400.000000
# 50%    2011.000000     1.024000   128.000000   600.000000   837.000000
# 75%    2015.000000     3.000000   256.000000   875.000000  1250.000000
# max    2023.000000   128.000000  8192.000000  2331.000000  2257.000000
#
#        unifiedShader          tmu          rop  pixelShader  vertexShader
# count    2065.000000  2889.000000  2889.000000   824.000000    824.000000
# mean     1032.937530    47.429214    18.750087     6.739078      2.622573
# std      1662.834618    73.014849    25.067896     8.091586      2.579388
# min         8.000000     0.000000     0.000000     0.000000      0.000000
# 25%       144.000000     8.000000     4.000000     2.000000      0.000000
# 50%       384.000000    20.000000     8.000000     4.000000      2.000000
# 75%      1280.000000    56.000000    24.000000     8.000000      4.000000
# max     17408.000000   880.000000   256.000000    48.000000     24.000000

# %%
gpu_df.sort_values(by="gpuClock")
# Out:
#      manufacturer               productName  releaseYear    memSize  \
# 2829          ATI            Graphics Ultra       1992.0   0.001000
# 2842          ATI  VGA Improved Performance       1987.0   0.000256
# 2841          ATI    Graphics Solution Plus       1987.0   0.000064
# 2840          ATI            EGA Wonder 800       1987.0   0.000256
# 2838          ATI            EGA Wonder 480       1988.0   0.000256
# ...           ...                       ...          ...        ...
# 37            AMD         Radeon RX 6500 XT       2022.0   4.000000
# 107           AMD         Radeon RX 6700 XT       2021.0  12.000000
# 46            AMD        Radeon RX 6850M XT       2022.0  12.000000
# 34            AMD          Radeon Pro W6400       2022.0   4.000000
# 97            AMD          Radeon Pro W6600       2021.0   8.000000
#
#       memBusWidth  gpuClock  memClock  unifiedShader  tmu  rop  pixelShader  \
# 2829         32.0        10      10.0            NaN    0    1          1.0
# 2842         32.0        10      10.0            NaN    0    1          1.0
# 2841         32.0        10       5.0            NaN    0    0          0.0
# 2840         32.0        10       8.0            NaN    0    1          1.0
# 2838         32.0        10       8.0            NaN    0    1          1.0
# ...           ...       ...       ...            ...  ...  ...          ...
# 37           64.0      2310    2248.0         1024.0   64   32          NaN
# 107         192.0      2321    2000.0         2560.0  160   64          NaN
# 46          192.0      2321    2000.0         2560.0  160   64          NaN
# 34           64.0      2331    1750.0          768.0   48   32          NaN
# 97          128.0      2331    1750.0         1792.0  112   64          NaN
#
#       vertexShader igp           bus memType    gpuChip
# 2829           0.0  No           PCI    VRAM      Mach8
# 2842           0.0  No           PCI    DRAM    16899-0
# 2841           0.0  No           PCI    DRAM  CW16800-B
# 2840           0.0  No           PCI    DRAM    16899-0
# 2838           0.0  No           PCI    DRAM    16899-0
# ...            ...  ..           ...     ...        ...
# 37             NaN  No   PCIe 4.0 x4   GDDR6    Navi 24
# 107            NaN  No  PCIe 4.0 x16   GDDR6    Navi 22
# 46             NaN  No  PCIe 4.0 x16   GDDR6    Navi 22
# 34             NaN  No   PCIe 4.0 x4   GDDR6    Navi 24
# 97             NaN  No  PCIe 4.0 x16   GDDR6    Navi 23
#
# [2889 rows x 16 columns]

# %%
gpu_df.sort_values(by="gpuClock",ascending=False)
# Out:
#      manufacturer             productName  releaseYear  memSize  memBusWidth  \
# 34            AMD        Radeon Pro W6400       2022.0    4.000         64.0
# 97            AMD        Radeon Pro W6600       2021.0    8.000        128.0
# 46            AMD      Radeon RX 6850M XT       2022.0   12.000        192.0
# 107           AMD       Radeon RX 6700 XT       2021.0   12.000        192.0
# 37            AMD       Radeon RX 6500 XT       2022.0    4.000         64.0
# ...           ...                     ...          ...      ...          ...
# 2831          ATI  Graphics Ultra Pro ISA       1992.0    0.002         64.0
# 2830          ATI  Graphics Ultra Pro ISA       1992.0    0.002         64.0
# 2829          ATI          Graphics Ultra       1992.0    0.001         32.0
# 2828          ATI              8514-Ultra       1992.0    0.001         32.0
# 2827          ATI  Graphics Ultra XLR VLB       1993.0    0.001         64.0
#
#       gpuClock  memClock  unifiedShader  tmu  rop  pixelShader  vertexShader  \
# 34        2331    1750.0          768.0   48   32          NaN           NaN
# 97        2331    1750.0         1792.0  112   64          NaN           NaN
# 46        2321    2000.0         2560.0  160   64          NaN           NaN
# 107       2321    2000.0         2560.0  160   64          NaN           NaN
# 37        2310    2248.0         1024.0   64   32          NaN           NaN
# ...        ...       ...            ...  ...  ...          ...           ...
# 2831        10      10.0            NaN    0    1          1.0           0.0
# 2830        10      10.0            NaN    0    1          1.0           0.0
# 2829        10      10.0            NaN    0    1          1.0           0.0
# 2828        10      10.0            NaN    0    1          1.0           0.0
# 2827        10      10.0            NaN    0    1          1.0           0.0
#
#      igp           bus memType  gpuChip
# 34    No   PCIe 4.0 x4   GDDR6  Navi 24
# 97    No  PCIe 4.0 x16   GDDR6  Navi 23
# 46    No  PCIe 4.0 x16   GDDR6  Navi 22
# 107   No  PCIe 4.0 x16   GDDR6  Navi 22
# 37    No   PCIe 4.0 x4   GDDR6  Navi 24
# ...   ..           ...     ...      ...
# 2831  No           PCI    DRAM   Mach32
# 2830  No           PCI    DRAM   Mach32
# 2829  No           PCI    VRAM    Mach8
# 2828  No           PCI    VRAM    Mach8
# 2827  No           PCI    VRAM   Mach32
#
# [2889 rows x 16 columns]

# %%
#Selecting a single column, which yields a Series, equivalent to df.A:
#.unique() eliminates duplicate values

a=gpu_df["productName"].unique()
b=gpu_df["releaseYear"].unique()

# %%
b,a
# Out:
# (array([2023., 2022., 2021., 2020., 2019., 2018., 2017., 2016., 2015.,
#         2014., 2013., 2012., 2011., 2010., 2009., 2008., 2007., 2006.,
#         2005., 2004., 2003., 2002., 2001., 2000., 1999., 1998., 1997.,
#         1996., 1995., 1994., 1993., 1992., 1990., 1988., 1987., 1986.,
#           nan]),
#  array(['GeForce RTX 4050', 'Arc A350M', 'Arc A370M', ..., 'Voodoo5 6000',
#         'Xe DG1', 'Xe DG1-SDV'], dtype=object))

# %%
##Selecting via [], which slices the rows:

gpu_df[10:23]  #this will select values from index 10 to index 22... 23 is excluded
# Out:
#    manufacturer                  productName  releaseYear  memSize  \
# 10       NVIDIA                GeForce MX550       2022.0      2.0
# 11       NVIDIA                GeForce MX570       2022.0      4.0
# 12       NVIDIA        GeForce RTX 3050 4 GB       2022.0      4.0
# 13       NVIDIA        GeForce RTX 3050 8 GB       2022.0      8.0
# 14       NVIDIA  GeForce RTX 3050 8 GB GA107       2022.0      8.0
# 15       NVIDIA         GeForce RTX 3050 OEM       2022.0      8.0
# 16       NVIDIA    GeForce RTX 3060 Ti GA103       2022.0      8.0
# 17       NVIDIA   GeForce RTX 3070 Ti Mobile       2022.0      8.0
# 18       NVIDIA       GeForce RTX 3080 12 GB       2022.0     12.0
# 19       NVIDIA    GeForce RTX 3080 Ti 20 GB       2022.0     20.0
# 20       NVIDIA    GeForce RTX 3080 Ti Max-Q       2022.0     16.0
# 21       NVIDIA   GeForce RTX 3080 Ti Mobile       2022.0     16.0
# 22       NVIDIA          GeForce RTX 3090 Ti       2022.0     24.0
#
#     memBusWidth  gpuClock  memClock  unifiedShader  tmu  rop  pixelShader  \
# 10         64.0      1065    1500.0         1024.0   32   16          NaN
# 11         64.0      1087    1500.0         2048.0   64   40          NaN
# 12        128.0      1545    1750.0         2304.0   72   32          NaN
# 13        128.0      1552    1750.0         2560.0   80   32          NaN
# 14        128.0      1552    1750.0         2560.0   80   32          NaN
# 15        128.0      1515    1750.0         2560.0   80   32          NaN
# 16        256.0      1410    1750.0         4864.0  152   80          NaN
# 17        256.0       915    1750.0         5632.0  176   80          NaN
# 18        384.0      1260    1188.0         8960.0  280   96          NaN
# 19        320.0      1335    1188.0        10240.0  320  112          NaN
# 20        256.0       585    1500.0         7424.0  232   96          NaN
# 21        256.0       810    2000.0         7424.0  232   96          NaN
# 22        384.0      1560    1313.0        10752.0  336  112          NaN
#
#     vertexShader igp           bus memType gpuChip
# 10           NaN  No   PCIe 4.0 x8   GDDR6   TU117
# 11           NaN  No   PCIe 4.0 x8   GDDR6  GA107S
# 12           NaN  No   PCIe 4.0 x8   GDDR6   GA107
# 13           NaN  No   PCIe 4.0 x8   GDDR6   GA106
# 14           NaN  No   PCIe 4.0 x8   GDDR6   GA107
# 15           NaN  No   PCIe 4.0 x8   GDDR6   GA106
# 16           NaN  No  PCIe 4.0 x16   GDDR6  GA103S
# 17           NaN  No  PCIe 4.0 x16   GDDR6   GA104
# 18           NaN  No  PCIe 4.0 x16  GDDR6X   GA102
# 19           NaN  No  PCIe 4.0 x16  GDDR6X   GA102
# 20           NaN  No  PCIe 4.0 x16   GDDR6  GA103S
# 21           NaN  No  PCIe 4.0 x16   GDDR6  GA103S
# 22           NaN  No  PCIe 4.0 x16  GDDR6X   GA102

# %%
#Selection by label
#selecting cross section ... i.e selecting value at particular index


gpu_df.iloc[6]
# Out:
# manufacturer            Intel
# productName          Arc A770
# releaseYear            2022.0
# memSize                  16.0
# memBusWidth             256.0
# gpuClock                  300
# memClock               1500.0
# unifiedShader          4096.0
# tmu                       256
# rop                       128
# pixelShader               NaN
# vertexShader              NaN
# igp                        No
# bus              PCIe 4.0 x16
# memType                 GDDR6
# gpuChip               DG2-512
# Name: 6, dtype: object

# %%
#Selecting on a multi-axis by label:

gpu_df.loc[10:20,["gpuClock","memClock"]]
# Out:
#     gpuClock  memClock
# 10      1065    1500.0
# 11      1087    1500.0
# 12      1545    1750.0
# 13      1552    1750.0
# 14      1552    1750.0
# 15      1515    1750.0
# 16      1410    1750.0
# 17       915    1750.0
# 18      1260    1188.0
# 19      1335    1188.0
# 20       585    1500.0

# %%
#For getting a scalar value:


gpu_df.loc[19,"gpuClock"]
#we are getting gpuClock value present at index 19
# Out:
# 1335

# %%
# selection By integer slices, acting similar to NumPy/Python:

gpu_df.iloc[10:20, 3:9] #this will select rows from 10-20, and columns from 3rd to 8th...
# Out:
#     memSize  memBusWidth  gpuClock  memClock  unifiedShader  tmu
# 10      2.0         64.0      1065    1500.0         1024.0   32
# 11      4.0         64.0      1087    1500.0         2048.0   64
# 12      4.0        128.0      1545    1750.0         2304.0   72
# 13      8.0        128.0      1552    1750.0         2560.0   80
# 14      8.0        128.0      1552    1750.0         2560.0   80
# 15      8.0        128.0      1515    1750.0         2560.0   80
# 16      8.0        256.0      1410    1750.0         4864.0  152
# 17      8.0        256.0       915    1750.0         5632.0  176
# 18     12.0        384.0      1260    1188.0         8960.0  280
# 19     20.0        320.0      1335    1188.0        10240.0  320

# %%
#Boolean indexing
#it will print/show those rows where memSize is greater than 10
gpu_df[gpu_df["memSize"]>10]
# Out:
#      manufacturer                productName  releaseYear  memSize  \
# 5           Intel                  Arc A730M       2022.0     12.0
# 6           Intel                   Arc A770       2022.0     16.0
# 7           Intel                  Arc A770M       2022.0     16.0
# 8           Intel                   Arc A780       2022.0     16.0
# 9           Intel             Arctic Sound-M       2022.0     16.0
# ...           ...                        ...          ...      ...
# 1186        Intel             Xeon Phi 7120P       2013.0     16.0
# 1187        Intel             Xeon Phi 7120X       2013.0     16.0
# 2853       NVIDIA  GeForce RTX 3070 Ti 16 GB          NaN     16.0
# 2866          AMD         Radeon Pro V7350X2          NaN     16.0
# 2869          AMD         Radeon RX 6900 XTX          NaN     16.0
#
#       memBusWidth  gpuClock  memClock  unifiedShader  tmu  rop  pixelShader  \
# 5           192.0       300    1500.0         3072.0  192   96          NaN
# 6           256.0       300    1500.0         4096.0  256  128          NaN
# 7           256.0       300    1500.0         4096.0  256  128          NaN
# 8           256.0       300    1093.0         4096.0  256  128          NaN
# 9          4096.0       900    1200.0         8192.0  256  128          NaN
# ...           ...       ...       ...            ...  ...  ...          ...
# 1186        512.0      1238    1375.0          976.0   32    0          NaN
# 1187        512.0      1238    1375.0          976.0   32    0          NaN
# 2853        256.0      1575    1188.0         6144.0  192   96          NaN
# 2866        256.0      1188    1750.0         2304.0  144   32          NaN
# 2869        256.0      2075    2250.0         5120.0  320  128          NaN
#
#       vertexShader igp           bus memType         gpuChip
# 5              NaN  No  PCIe 4.0 x16   GDDR6         DG2-512
# 6              NaN  No  PCIe 4.0 x16   GDDR6         DG2-512
# 7              NaN  No  PCIe 4.0 x16   GDDR6         DG2-512
# 8              NaN  No  PCIe 4.0 x16  GDDR6X         DG2-512
# 9              NaN  No  PCIe 4.0 x16   HBM2e    Arctic Sound
# ...            ...  ..           ...     ...             ...
# 1186           NaN  No  PCIe 3.0 x16   GDDR5  Knights Corner
# 1187           NaN  No  PCIe 3.0 x16   GDDR5  Knights Corner
# 2853           NaN  No  PCIe 4.0 x16  GDDR6X           GA104
# 2866           NaN  No  PCIe 3.0 x16   GDDR5       Ellesmere
# 2869           NaN  No  PCIe 4.0 x16   GDDR6         Navi 21
#
# [159 rows x 16 columns]

# %% [markdown]
# # SETTING/APPENDING

# %%
#setting up a new column

s=pd.Series(np.random.rand(2889))
s
# Out:
# 0       0.301238
# 1       0.854746
# 2       0.646386
# 3       0.366595
# 4       0.005925
#           ...
# 2884    0.157377
# 2885    0.139304
# 2886    0.677035
# 2887    0.288926
# 2888    0.091029
# Length: 2889, dtype: float64

# %%
# Out:
# 0       0.162932
# 1       0.258576
# 2       0.006955
# 3       0.462313
# 4       0.050218
#           ...
# 2884    0.438216
# 2885    0.436368
# 2886    0.502154
# 2887    0.217004
# 2888    0.820694
# Length: 2889, dtype: float64

# %%
gpu_df["new_col"]=s  #we appended new_col at the rightmost end of our dataFrame

# %%
gpu_df.head(10)
# Out:
#   manufacturer       productName  releaseYear  memSize  memBusWidth  gpuClock  \
# 0       NVIDIA  GeForce RTX 4050       2023.0      8.0        128.0      1925
# 1        Intel         Arc A350M       2022.0      4.0         64.0       300
# 2        Intel         Arc A370M       2022.0      4.0         64.0       300
# 3        Intel          Arc A380       2022.0      4.0         64.0       300
# 4        Intel         Arc A550M       2022.0      8.0        128.0       300
# 5        Intel         Arc A730M       2022.0     12.0        192.0       300
# 6        Intel          Arc A770       2022.0     16.0        256.0       300
# 7        Intel         Arc A770M       2022.0     16.0        256.0       300
# 8        Intel          Arc A780       2022.0     16.0        256.0       300
# 9        Intel    Arctic Sound-M       2022.0     16.0       4096.0       900
#
#    memClock  unifiedShader  tmu  rop  pixelShader  vertexShader igp  \
# 0    2250.0         3840.0  120   48          NaN           NaN  No
# 1    1500.0          768.0   48   24          NaN           NaN  No
# 2    1500.0         1024.0   64   32          NaN           NaN  No
# 3    1500.0         1024.0   64   32          NaN           NaN  No
# 4    1500.0         2048.0  128   64          NaN           NaN  No
# 5    1500.0         3072.0  192   96          NaN           NaN  No
# 6    1500.0         4096.0  256  128          NaN           NaN  No
# 7    1500.0         4096.0  256  128          NaN           NaN  No
# 8    1093.0         4096.0  256  128          NaN           NaN  No
# 9    1200.0         8192.0  256  128          NaN           NaN  No
#
#             bus memType       gpuChip   new_col
# 0  PCIe 4.0 x16   GDDR6         AD106  0.301238
# 1   PCIe 4.0 x8   GDDR6       DG2-128  0.854746
# 2   PCIe 4.0 x8   GDDR6       DG2-128  0.646386
# 3   PCIe 4.0 x8   GDDR6       DG2-128  0.366595
# 4  PCIe 4.0 x16   GDDR6       DG2-512  0.005925
# 5  PCIe 4.0 x16   GDDR6       DG2-512  0.648927
# 6  PCIe 4.0 x16   GDDR6       DG2-512  0.407142
# 7  PCIe 4.0 x16   GDDR6       DG2-512  0.917086
# 8  PCIe 4.0 x16  GDDR6X       DG2-512  0.464630
# 9  PCIe 4.0 x16   HBM2e  Arctic Sound  0.957726

# %% [markdown]
# # handeling Missing data

# %%
df2=gpu_df.iloc[: , :7]

# %%
df2
# Out:
#      manufacturer       productName  releaseYear  memSize  memBusWidth  \
# 0          NVIDIA  GeForce RTX 4050       2023.0    8.000        128.0
# 1           Intel         Arc A350M       2022.0    4.000         64.0
# 2           Intel         Arc A370M       2022.0    4.000         64.0
# 3           Intel          Arc A380       2022.0    4.000         64.0
# 4           Intel         Arc A550M       2022.0    8.000        128.0
# ...           ...               ...          ...      ...          ...
# 2884         3dfx  Voodoo5 5000 AGP          NaN    0.016        128.0
# 2885         3dfx  Voodoo5 5000 PCI          NaN    0.016        128.0
# 2886         3dfx      Voodoo5 6000          NaN    0.032        128.0
# 2887        Intel            Xe DG1          NaN    4.000        128.0
# 2888        Intel        Xe DG1-SDV          NaN    8.000        128.0
#
#       gpuClock  memClock
# 0         1925    2250.0
# 1          300    1500.0
# 2          300    1500.0
# 3          300    1500.0
# 4          300    1500.0
# ...        ...       ...
# 2884       166     166.0
# 2885       166     166.0
# 2886       166     166.0
# 2887       900    2133.0
# 2888       900    2133.0
#
# [2889 rows x 7 columns]

# %%
df2.dropna()  #as we can see here it dropped rows containing NaN values.. original rows=2889, after dropna= 2433
# Out:
#      manufacturer               productName  releaseYear   memSize  \
# 0          NVIDIA          GeForce RTX 4050       2023.0  8.000000
# 1           Intel                 Arc A350M       2022.0  4.000000
# 2           Intel                 Arc A370M       2022.0  4.000000
# 3           Intel                  Arc A380       2022.0  4.000000
# 4           Intel                 Arc A550M       2022.0  8.000000
# ...           ...                       ...          ...       ...
# 2840          ATI            EGA Wonder 800       1987.0  0.000256
# 2841          ATI    Graphics Solution Plus       1987.0  0.000064
# 2842          ATI  VGA Improved Performance       1987.0  0.000256
# 2843          ATI      Color Emulation Card       1986.0  0.000032
# 2844          ATI         Graphics Solution       1986.0  0.000064
#
#       memBusWidth  gpuClock  memClock
# 0           128.0      1925    2250.0
# 1            64.0       300    1500.0
# 2            64.0       300    1500.0
# 3            64.0       300    1500.0
# 4           128.0       300    1500.0
# ...           ...       ...       ...
# 2840         32.0        10       8.0
# 2841         32.0        10       5.0
# 2842         32.0        10      10.0
# 2843         32.0        10       5.0
# 2844         32.0        10       5.0
#
# [2433 rows x 7 columns]

# %%
#filling Nan values with some assigned value


df2.fillna(value=7)
# Out:
#      manufacturer       productName  releaseYear  memSize  memBusWidth  \
# 0          NVIDIA  GeForce RTX 4050       2023.0    8.000        128.0
# 1           Intel         Arc A350M       2022.0    4.000         64.0
# 2           Intel         Arc A370M       2022.0    4.000         64.0
# 3           Intel          Arc A380       2022.0    4.000         64.0
# 4           Intel         Arc A550M       2022.0    8.000        128.0
# ...           ...               ...          ...      ...          ...
# 2884         3dfx  Voodoo5 5000 AGP          7.0    0.016        128.0
# 2885         3dfx  Voodoo5 5000 PCI          7.0    0.016        128.0
# 2886         3dfx      Voodoo5 6000          7.0    0.032        128.0
# 2887        Intel            Xe DG1          7.0    4.000        128.0
# 2888        Intel        Xe DG1-SDV          7.0    8.000        128.0
#
#       gpuClock  memClock
# 0         1925    2250.0
# 1          300    1500.0
# 2          300    1500.0
# 3          300    1500.0
# 4          300    1500.0
# ...        ...       ...
# 2884       166     166.0
# 2885       166     166.0
# 2886       166     166.0
# 2887       900    2133.0
# 2888       900    2133.0
#
# [2889 rows x 7 columns]

# %%
#getting masked values  true/false 
#true if value is Nan    false otherwise
pd.isna(df2)
# Out:
#       manufacturer  productName  releaseYear  memSize  memBusWidth  gpuClock  \
# 0            False        False        False    False        False     False
# 1            False        False        False    False        False     False
# 2            False        False        False    False        False     False
# 3            False        False        False    False        False     False
# 4            False        False        False    False        False     False
# ...            ...          ...          ...      ...          ...       ...
# 2884         False        False         True    False        False     False
# 2885         False        False         True    False        False     False
# 2886         False        False         True    False        False     False
# 2887         False        False         True    False        False     False
# 2888         False        False         True    False        False     False
#
#       memClock
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ...        ...
# 2884     False
# 2885     False
# 2886     False
# 2887     False
# 2888     False
#
# [2889 rows x 7 columns]

# %% [markdown]
# #  Operations

# %%
df3=gpu_df.iloc[: , 2:7]


#finding mean of columns
df3.mean()
# Out:
# releaseYear    2010.691388
# memSize           3.113803
# memBusWidth     274.874445
# gpuClock        661.126687
# memClock        868.578119
# dtype: float64

# %%
df3
# Out:
#       releaseYear  memSize  memBusWidth  gpuClock  memClock
# 0          2023.0    8.000        128.0      1925    2250.0
# 1          2022.0    4.000         64.0       300    1500.0
# 2          2022.0    4.000         64.0       300    1500.0
# 3          2022.0    4.000         64.0       300    1500.0
# 4          2022.0    8.000        128.0       300    1500.0
# ...           ...      ...          ...       ...       ...
# 2884          NaN    0.016        128.0       166     166.0
# 2885          NaN    0.016        128.0       166     166.0
# 2886          NaN    0.032        128.0       166     166.0
# 2887          NaN    4.000        128.0       900    2133.0
# 2888          NaN    8.000        128.0       900    2133.0
#
# [2889 rows x 5 columns]

# %% [markdown]
# # Apply
# Applying functions to the data:

# %%
df3.apply(np.cumsum) #cumsum ==cumulative sum
# Out:
#       releaseYear      memSize  memBusWidth  gpuClock   memClock
# 0          2023.0     8.000000        128.0      1925     2250.0
# 1          4045.0    12.000000        192.0      2225     3750.0
# 2          6067.0    16.000000        256.0      2525     5250.0
# 3          8089.0    20.000000        320.0      2825     6750.0
# 4         10111.0    28.000000        448.0      3125     8250.0
# ...           ...          ...          ...       ...        ...
# 2884          NaN  7700.841952     680352.0   1907863  2146870.0
# 2885          NaN  7700.857952     680480.0   1908029  2147036.0
# 2886          NaN  7700.889952     680608.0   1908195  2147202.0
# 2887          NaN  7704.889952     680736.0   1909095  2149335.0
# 2888          NaN  7712.889952     680864.0   1909995  2151468.0
#
# [2889 rows x 5 columns]

# %%
df3.cummax().head(30)
# Out:
#     releaseYear  memSize  memBusWidth  gpuClock  memClock
# 0        2023.0      8.0        128.0      1925    2250.0
# 1        2023.0      8.0        128.0      1925    2250.0
# 2        2023.0      8.0        128.0      1925    2250.0
# 3        2023.0      8.0        128.0      1925    2250.0
# 4        2023.0      8.0        128.0      1925    2250.0
# 5        2023.0     12.0        192.0      1925    2250.0
# 6        2023.0     16.0        256.0      1925    2250.0
# 7        2023.0     16.0        256.0      1925    2250.0
# 8        2023.0     16.0        256.0      1925    2250.0
# 9        2023.0     16.0       4096.0      1925    2250.0
# 10       2023.0     16.0       4096.0      1925    2250.0
# 11       2023.0     16.0       4096.0      1925    2250.0
# 12       2023.0     16.0       4096.0      1925    2250.0
# 13       2023.0     16.0       4096.0      1925    2250.0
# 14       2023.0     16.0       4096.0      1925    2250.0
# 15       2023.0     16.0       4096.0      1925    2250.0
# 16       2023.0     16.0       4096.0      1925    2250.0
# 17       2023.0     16.0       4096.0      1925    2250.0
# 18       2023.0     16.0       4096.0      1925    2250.0
# 19       2023.0     20.0       4096.0      1925    2250.0
# 20       2023.0     20.0       4096.0      1925    2250.0
# 21       2023.0     20.0       4096.0      1925    2250.0
# 22       2023.0     24.0       4096.0      1925    2250.0
# 23       2023.0     24.0       4096.0      1925    2250.0
# 24       2023.0     24.0       4096.0      1925    2250.0
# 25       2023.0     24.0       4096.0      1925    2250.0
# 26       2023.0     24.0       4096.0      1925    2250.0
# 27       2023.0     24.0       4096.0      1925    2250.0
# 28       2023.0     80.0       5120.0      1925    2250.0
# 29       2023.0     80.0       5120.0      1925    2250.0

# %%
df3
# Out:
#       releaseYear  memSize  memBusWidth  gpuClock  memClock
# 0          2023.0    8.000        128.0      1925    2250.0
# 1          2022.0    4.000         64.0       300    1500.0
# 2          2022.0    4.000         64.0       300    1500.0
# 3          2022.0    4.000         64.0       300    1500.0
# 4          2022.0    8.000        128.0       300    1500.0
# ...           ...      ...          ...       ...       ...
# 2884          NaN    0.016        128.0       166     166.0
# 2885          NaN    0.016        128.0       166     166.0
# 2886          NaN    0.032        128.0       166     166.0
# 2887          NaN    4.000        128.0       900    2133.0
# 2888          NaN    8.000        128.0       900    2133.0
#
# [2889 rows x 5 columns]

# %%
#it will show max-min value for each column

df3.apply(lambda x: x.max() - x.min())
# Out:
# releaseYear      37.000000
# memSize         127.999968
# memBusWidth    8160.000000
# gpuClock       2321.000000
# memClock       2252.000000
# dtype: float64

# %%
#counts or returns the number of time particular value has been occured

df3["releaseYear"].value_counts()
# Out:
# 2013.0    225
# 2008.0    174
# 2012.0    173
# 2011.0    170
# 2015.0    165
# 2007.0    156
# 2014.0    149
# 2010.0    148
# 2004.0    132
# 2006.0    129
# 2003.0    120
# 2017.0    110
# 2016.0    109
# 2009.0    106
# 2019.0    105
# 2005.0     97
# 2018.0     93
# 2021.0     88
# 2020.0     86
# 2002.0     70
# 2022.0     57
# 2001.0     41
# 1999.0     41
# 2000.0     32
# 1998.0     21
# 1997.0      9
# 1995.0      9
# 1996.0      8
# 1992.0      8
# 1987.0      3
# 1993.0      3
# 1988.0      2
# 1986.0      2
# 1990.0      2
# 1994.0      1
# 2023.0      1
# Name: releaseYear, dtype: int64

# %%
df3.groupby("releaseYear").sum()
# Out:
#                  memSize  memBusWidth  gpuClock  memClock
# releaseYear
# 1986.0          0.000096         64.0        20      10.0
# 1987.0          0.000576         96.0        30      23.0
# 1988.0          0.000512         64.0        35      16.0
# 1990.0          0.000768         64.0        20      20.0
# 1992.0          0.010000        384.0        80      80.0
# 1993.0          0.003000        192.0        86     103.0
# 1994.0          0.001000         32.0        53      33.0
# 1995.0          0.016000        576.0       452     416.0
# 1996.0          0.023000        576.0       458     572.0
# 1997.0          0.047000        672.0       703     733.0
# 1998.0          0.274000       1856.0      1843    1957.0
# 1999.0          0.804000       4128.0      4766    5248.0
# 2000.0          1.212000       6272.0      5224    5098.0
# 2001.0          1.988000       6368.0      8153    7365.0
# 2002.0          5.360000       8096.0     17108   14045.0
# 2003.0         14.848000      15808.0     35806   30865.0
# 2004.0         20.306000      20224.0     48153   40581.0
# 2005.0         20.868000      17760.0     39591   35837.0
# 2006.0         33.056000      18688.0     59401   57278.0
# 2007.0         50.982000      22432.0     81759   70043.0
# 2008.0        100.560000      27968.0     98105  103895.0
# 2009.0         78.016000      16448.0     61966   74850.0
# 2010.0        146.040000      20608.0     90720  110134.0
# 2011.0        229.928000      25792.0    109572  124203.0
# 2012.0        275.672000      24640.0    120416  143414.0
# 2013.0        480.912000      33152.0    167465  200985.0
# 2014.0        363.840000      20160.0    117725  131639.0
# 2015.0        483.384000      33344.0    135566  159060.0
# 2016.0        569.072000      46144.0    103470  121044.0
# 2017.0        601.024000      51232.0    118245  141476.0
# 2018.0        777.000000      62848.0     92557  100051.0
# 2019.0        602.750000      44768.0    104589  123715.0
# 2020.0        845.000000      52064.0     87825  105330.0
# 2021.0       1204.000000      59552.0     93654  117701.0
# 2022.0        672.000000      22752.0     73227   85945.0
# 2023.0          8.000000        128.0      1925    2250.0

# %%
#this works like sql query, first it will groupe/devide by 1st value, then group by 2nd.. and so on

df3.groupby(["releaseYear","gpuClock"]).sum()
# Out:
#                         memSize  memBusWidth  memClock
# releaseYear gpuClock
# 1986.0      10         0.000096         64.0      10.0
# 1987.0      10         0.000576         96.0      23.0
# 1988.0      10         0.000256         32.0       8.0
#             25         0.000256         32.0       8.0
# 1990.0      10         0.000768         64.0      20.0
# ...                         ...          ...       ...
# 2022.0      2150      12.000000        192.0    2250.0
#             2310       4.000000         64.0    2248.0
#             2321      12.000000        192.0    2000.0
#             2331       4.000000         64.0    1750.0
# 2023.0      1925       8.000000        128.0    2250.0
#
# [1097 rows x 3 columns]

# %% [markdown]
# # Time series
# pandas has simple, powerful, and efficient functionality for performing resampling operations during frequency con-
# version (e.g., converting secondly data into 5-minutely data). This is extremely common in, but not limited to, financial
# applications.

# %%
rng = pd.date_range("1/1/2012", periods=100, freq="S")
rng
# Out:
# DatetimeIndex(['2012-01-01 00:00:00', '2012-01-01 00:00:01',
#                '2012-01-01 00:00:02', '2012-01-01 00:00:03',
#                '2012-01-01 00:00:04', '2012-01-01 00:00:05',
#                '2012-01-01 00:00:06', '2012-01-01 00:00:07',
#                '2012-01-01 00:00:08', '2012-01-01 00:00:09',
#                '2012-01-01 00:00:10', '2012-01-01 00:00:11',
#                '2012-01-01 00:00:12', '2012-01-01 00:00:13',
#                '2012-01-01 00:00:14', '2012-01-01 00:00:15',
#                '2012-01-01 00:00:16', '2012-01-01 00:00:17',
#                '2012-01-01 00:00:18', '2012-01-01 00:00:19',
#                '2012-01-01 00:00:20', '2012-01-01 00:00:21',
#                '2012-01-01 00:00:22', '2012-01-01 00:00:23',
#                '2012-01-01 00:00:24', '2012-01-01 00:00:25',
#                '2012-01-01 00:00:26', '2012-01-01 00:00:27',
#                '2012-01-01 00:00:28', '2012-01-01 00:00:29',
#                '2012-01-01 00:00:30', '2012-01-01 00:00:31',
#                '2012-01-01 00:00:32', '2012-01-01 00:00:33',
#                '2012-01-01 00:00:34', '2012-01-01 00:00:35',
#                '2012-01-01 00:00:36', '2012-01-01 00:00:37',
#                '2012-01-01 00:00:38', '2012-01-01 00:00:39',
#                '2012-01-01 00:00:40', '2012-01-01 00:00:41',
#                '2012-01-01 00:00:42', '2012-01-01 00:00:43',
#                '2012-01-01 00:00:44', '2012-01-01 00:00:45',
#                '2012-01-01 00:00:46', '2012-01-01 00:00:47',
#                '2012-01-01 00:00:48', '2012-01-01 00:00:49',
#                '2012-01-01 00:00:50', '2012-01-01 00:00:51',
#                '2012-01-01 00:00:52', '2012-01-01 00:00:53',
#                '2012-01-01 00:00:54', '2012-01-01 00:00:55',
#                '2012-01-01 00:00:56', '2012-01-01 00:00:57',
#                '2012-01-01 00:00:58', '2012-01-01 00:00:59',
#                '2012-01-01 00:01:00', '2012-01-01 00:01:01',
#                '2012-01-01 00:01:02', '2012-01-01 00:01:03',
#                '2012-01-01 00:01:04', '2012-01-01 00:01:05',
#                '2012-01-01 00:01:06', '2012-01-01 00:01:07',
#                '2012-01-01 00:01:08', '2012-01-01 00:01:09',
#                '2012-01-01 00:01:10', '2012-01-01 00:01:11',
#                '2012-01-01 00:01:12', '2012-01-01 00:01:13',
#                '2012-01-01 00:01:14', '2012-01-01 00:01:15',
#                '2012-01-01 00:01:16', '2012-01-01 00:01:17',
#                '2012-01-01 00:01:18', '2012-01-01 00:01:19',
#                '2012-01-01 00:01:20', '2012-01-01 00:01:21',
#                '2012-01-01 00:01:22', '2012-01-01 00:01:23',
#                '2012-01-01 00:01:24', '2012-01-01 00:01:25',
#                '2012-01-01 00:01:26', '2012-01-01 00:01:27',
#                '2012-01-01 00:01:28', '2012-01-01 00:01:29',
#                '2012-01-01 00:01:30', '2012-01-01 00:01:31',
#                '2012-01-01 00:01:32', '2012-01-01 00:01:33',
#                '2012-01-01 00:01:34', '2012-01-01 00:01:35',
#                '2012-01-01 00:01:36', '2012-01-01 00:01:37',
#                '2012-01-01 00:01:38', '2012-01-01 00:01:39'],
#               dtype='datetime64[ns]', freq='S')

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
ts
# Out:
# 2012-01-01 00:00:00    269
# 2012-01-01 00:00:01      7
# 2012-01-01 00:00:02    399
# 2012-01-01 00:00:03    205
# 2012-01-01 00:00:04    322
#                       ...
# 2012-01-01 00:01:35    156
# 2012-01-01 00:01:36     35
# 2012-01-01 00:01:37     11
# 2012-01-01 00:01:38    251
# 2012-01-01 00:01:39    438
# Freq: S, Length: 100, dtype: int64

# %%
ts.resample("5Min").sum()
# Out:
# 2012-01-01    25263
# Freq: 5T, dtype: int64

# %%
rng = pd.date_range("3/6/2012 00:00", periods=100, freq="D")

# %%
rng
# Out:
# DatetimeIndex(['2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
#                '2012-03-10', '2012-03-11', '2012-03-12', '2012-03-13',
#                '2012-03-14', '2012-03-15', '2012-03-16', '2012-03-17',
#                '2012-03-18', '2012-03-19', '2012-03-20', '2012-03-21',
#                '2012-03-22', '2012-03-23', '2012-03-24', '2012-03-25',
#                '2012-03-26', '2012-03-27', '2012-03-28', '2012-03-29',
#                '2012-03-30', '2012-03-31', '2012-04-01', '2012-04-02',
#                '2012-04-03', '2012-04-04', '2012-04-05', '2012-04-06',
#                '2012-04-07', '2012-04-08', '2012-04-09', '2012-04-10',
#                '2012-04-11', '2012-04-12', '2012-04-13', '2012-04-14',
#                '2012-04-15', '2012-04-16', '2012-04-17', '2012-04-18',
#                '2012-04-19', '2012-04-20', '2012-04-21', '2012-04-22',
#                '2012-04-23', '2012-04-24', '2012-04-25', '2012-04-26',
#                '2012-04-27', '2012-04-28', '2012-04-29', '2012-04-30',
#                '2012-05-01', '2012-05-02', '2012-05-03', '2012-05-04',
#                '2012-05-05', '2012-05-06', '2012-05-07', '2012-05-08',
#                '2012-05-09', '2012-05-10', '2012-05-11', '2012-05-12',
#                '2012-05-13', '2012-05-14', '2012-05-15', '2012-05-16',
#                '2012-05-17', '2012-05-18', '2012-05-19', '2012-05-20',
#                '2012-05-21', '2012-05-22', '2012-05-23', '2012-05-24',
#                '2012-05-25', '2012-05-26', '2012-05-27', '2012-05-28',
#                '2012-05-29', '2012-05-30', '2012-05-31', '2012-06-01',
#                '2012-06-02', '2012-06-03', '2012-06-04', '2012-06-05',
#                '2012-06-06', '2012-06-07', '2012-06-08', '2012-06-09',
#                '2012-06-10', '2012-06-11', '2012-06-12', '2012-06-13'],
#               dtype='datetime64[ns]', freq='D')

# %%
ts = pd.Series(np.random.randn(len(rng)), rng)

# %%
ts
# Out:
# 2012-03-06   -2.315210
# 2012-03-07    0.645906
# 2012-03-08    0.505145
# 2012-03-09   -1.136596
# 2012-03-10    0.875005
#                 ...
# 2012-06-09    0.892278
# 2012-06-10   -0.272271
# 2012-06-11   -0.353001
# 2012-06-12   -0.868946
# 2012-06-13   -1.727349
# Freq: D, Length: 100, dtype: float64

# %%
ts_utc = ts.tz_localize("UTC") #converting to UTC Timezone

# %%
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00   -2.315210
# 2012-03-07 00:00:00+00:00    0.645906
# 2012-03-08 00:00:00+00:00    0.505145
# 2012-03-09 00:00:00+00:00   -1.136596
# 2012-03-10 00:00:00+00:00    0.875005
#                                ...
# 2012-06-09 00:00:00+00:00    0.892278
# 2012-06-10 00:00:00+00:00   -0.272271
# 2012-06-11 00:00:00+00:00   -0.353001
# 2012-06-12 00:00:00+00:00   -0.868946
# 2012-06-13 00:00:00+00:00   -1.727349
# Freq: D, Length: 100, dtype: float64

# %%
ts_utc.tz_convert("US/Eastern")
# Out:
# 2012-03-05 19:00:00-05:00   -2.315210
# 2012-03-06 19:00:00-05:00    0.645906
# 2012-03-07 19:00:00-05:00    0.505145
# 2012-03-08 19:00:00-05:00   -1.136596
# 2012-03-09 19:00:00-05:00    0.875005
#                                ...
# 2012-06-08 20:00:00-04:00    0.892278
# 2012-06-09 20:00:00-04:00   -0.272271
# 2012-06-10 20:00:00-04:00   -0.353001
# 2012-06-11 20:00:00-04:00   -0.868946
# 2012-06-12 20:00:00-04:00   -1.727349
# Freq: D, Length: 100, dtype: float64

# %% [markdown]
# # Categorical DATA
# pandas can include categorical data in a DataFrame.

# %%
df = pd.DataFrame(
{"id": [1, 2, 3, 4, 5, 6], "raw_grade": ["a", "b", "b", "a", "a", "e"]}
)

df["raw_grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: raw_grade, dtype: object

# %%
#Converting the raw grades to a categorical data type:

df["grade"] = df["raw_grade"].astype("category")

# %%
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
#Rename the categories to more meaningful names (assigning to Series.cat.categories() is in place!):

# %%
df["grade"].cat.categories = ["very good", "good", "very bad"]

df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (3, object): ['very good', 'good', 'very bad']

# %%
df["grade"] = df["grade"].cat.set_categories(

["very bad", "bad", "medium", "good", "very good"]
)

# %%
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %%
df.groupby(["grade"]).size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %% [markdown]
# # Getting data in/out

# %% [markdown]
# 1.writing to csv

# %%
df.to_csv("1.csv")

# %%
pd.read_csv("1.csv")
# Out:
#    Unnamed: 0  id raw_grade      grade
# 0           0   1         a  very good
# 1           1   2         b       good
# 2           2   3         b       good
# 3           3   4         a  very good
# 4           4   5         a  very good
# 5           5   6         e   very bad

# %% [markdown]
# 2.HDF5
#
# Reading and writing to HDFStores.
#
# Writing to a HDF5 Store:

# %%
df.to_hdf("2.h5", "df",format="table")

# %%
#Reading from a HDF5 Store:

pd.read_hdf("2.h5", "df")
# Out:
#    id raw_grade      grade
# 0   1         a  very good
# 1   2         b       good
# 2   3         b       good
# 3   4         a  very good
# 4   5         a  very good
# 5   6         e   very bad

# %% [markdown]
# 3.EXCEL

# %%
df3.to_excel("3.xlsx", sheet_name="Sheet1")

# %%
pd.read_excel("3.xlsx","Sheet1",index_col=None, na_values=["NA"])
# Out:
#       Unnamed: 0  releaseYear  memSize  memBusWidth  gpuClock  memClock
# 0              0       2023.0    8.000        128.0      1925    2250.0
# 1              1       2022.0    4.000         64.0       300    1500.0
# 2              2       2022.0    4.000         64.0       300    1500.0
# 3              3       2022.0    4.000         64.0       300    1500.0
# 4              4       2022.0    8.000        128.0       300    1500.0
# ...          ...          ...      ...          ...       ...       ...
# 2884        2884          NaN    0.016        128.0       166     166.0
# 2885        2885          NaN    0.016        128.0       166     166.0
# 2886        2886          NaN    0.032        128.0       166     166.0
# 2887        2887          NaN    4.000        128.0       900    2133.0
# 2888        2888          NaN    8.000        128.0       900    2133.0
#
# [2889 rows x 6 columns]
